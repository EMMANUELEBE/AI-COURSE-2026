# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Generate random data
data = np.random.randn(1000)

# 2. Plot a histogram
plt.hist(data, bins=30, color='purple', edgecolor='black')
plt.title("My AI Environment is Working!")
plt.show()
